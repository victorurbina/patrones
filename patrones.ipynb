# %% [markdown]
# ### Cargada de datos de los diferentes excel

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as mp

excelTvLg = 'TvLg.xlsx'
excelTvRecco = 'TvRecco.xlsx'
excelMicroOndas='MicroOndas.xlsx'
excelLavadora='Lavadora(CargaMaxima).xlsx'
excelNoteToshiva='NoteToshiva.xlsx'
excelNoteHp='NoteHp.xlsx'
excelNoteSamsung='NoteSamsung.xlsx'
excelRouterLgVTR='RouterLgVTR.xlsx'

df_TvLg = pd.read_excel(excelTvLg)
df_TvRecco = pd.read_excel(excelTvRecco)
df_MicroOndas=pd.read_excel(excelMicroOndas)
df_Lavadora=pd.read_excel(excelLavadora)
df_NoteToshiva=pd.read_excel(excelNoteToshiva)
df_NoteHp=pd.read_excel(excelNoteHp)
df_NoteSamsung=pd.read_excel(excelNoteSamsung)
df_RouterLgVTR=pd.read_excel(excelRouterLgVTR)

# %% [markdown]
# ### Gráficos

# %%
Fp=df_RouterLgVTR['Factor de Potencia']
Id=df_RouterLgVTR['ID']

#FpNoteHp=df_NoteHp['Factor de Potencia']
#IdNoteHp=df_NoteHp['ID']

#FpNoteSamsung=df_NoteSamsung['Factor de Potencia']
#IdNoteSamsung=df_NoteSamsung['ID']

mp.plot(Id,Fp)
mp.legend(('FP'))
mp.ylabel('Factor de Potencia')
mp.xlabel('Momento')


#mp.plot(IdNoteToshiva,FpNoteToshiva,IdNoteHp,FpNoteHp,IdNoteSamsung,FpNoteSamsung)
#mp.legend(("FpNoteToshiva","FpNoteHp","FpNoteSamsung"))
#mp.ylabel('Factor de Potencia')
#mp.xlabel('Momento')
mp.show()
